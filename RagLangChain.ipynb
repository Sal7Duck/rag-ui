# %% [markdown]
# <a href="https://colab.research.google.com/github/Sal7Duck/rag-ui/blob/code-cleaning/RagLangChain.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
home_dir = "/Users/saloni/Desktop/rag-ui/data/"

# %%
import datetime
import glob
import os.path
import pickle
import urllib.request
from bs4 import BeautifulSoup
import requests

# %%
dir_data_path = home_dir + "{}/"
file_name = "{}.html"
output_filename = "final_output_text.pkl"
all_directories = ["notification_1991_2023", "notifications_not_in_toc", "rbi_notification_2023_1991"]
verbose = 100

# %%
def get_text_from_html(html_file_path):
    html_file = open(html_file_path, 'r')
    html = html_file.read()
    #using BeautifulSoup to scrape text
    soup = BeautifulSoup(html)

    #kill all script and style elements
    for script in soup(["script", "style"]):
        script.extract()

    #get text
    text = soup.get_text()
    #break into lines and remmove leading and trailing spaces on each
    lines = (line.strip() for line in text.splitlines())
    #break multi headlines into a line each
    chunks = [phrase.strip() for line in lines for phrase in line.split(" ")]
    #drop blank lines
    text = '\n'.join([chunk for chunk in chunks])
    return text

# %%
if __name__ == '__main__':
    extracted_text_all_dirs = {}
    for directory_name in all_directories:
        extracted_text_all_dirs[directory_name] = {}

    #for all html files in all three directories, extract text and store in above object
    for directory_name in all_directories:
        dir_data_path_current = dir_data_path.format(directory_name)

        print(f"\n====== Current Directory : {directory_name} ======")
        start_time = datetime.datetime.now()

        #iterate over all nested pkl files
        for counter, html_file_path in enumerate(glob.glob(dir_data_path_current + "*.html")):
            text = get_text_from_html(html_file_path)
            file_name = html_file_path.split("/")[-1].split(".")[0]
            extracted_text_all_dirs[directory_name][file_name] = text

            if counter%verbose == 0:
                end_time = datetime.datetime.now()
                elapsed_time = end_time - start_time
                elapsed_seconds = elapsed_time.total_seconds()
                print(f"Total files completed : {counter + 1} in {elapsed_seconds} s")

            if os.path.exists(home_dir + output_filename):
                os.remove(home_dir + output_filename)

            with open(home_dir + output_filename, 'wb') as f:
                pickle.dump(extracted_text_all_dirs, f)

print("Completed!")
# Out:
# ====== Current Directory : notification_1991_2023 ======
# Total files completed : 1 in 0.084903 s
# Total files completed : 101 in 1.758584 s
# Total files completed : 201 in 3.895285 s
# Total files completed : 301 in 5.603861 s
# Total files completed : 401 in 7.545203 s
# Total files completed : 501 in 9.217782 s
# Total files completed : 601 in 11.124743 s
# Total files completed : 701 in 13.223793 s
# Total files completed : 801 in 15.184521 s
# Total files completed : 901 in 17.200728 s
# Total files completed : 1001 in 19.522926 s
# Total files completed : 1101 in 21.557409 s
# Total files completed : 1201 in 23.719619 s
# Total files completed : 1301 in 26.399114 s
# Total files completed : 1401 in 28.568659 s
# Total files completed : 1501 in 31.899686 s
# Total files completed : 1601 in 35.488755 s
# Total files completed : 1701 in 39.172677 s
# Total files completed : 1801 in 42.560626 s
# Total files completed : 1901 in 46.433572 s
# Total files completed : 2001 in 49.888493 s
# Total files completed : 2101 in 53.543945 s
# Total files completed : 4301 in 816.054834 s
# Total files completed : 4401 in 843.73231 s
# Total files completed : 4501 in 872.296284 s
# Total files completed : 4601 in 907.412592 s
# Total files completed : 4701 in 938.996751 s
# Total files completed : 4801 in 966.331357 s
# Total files completed : 4901 in 997.888153 s
# Total files completed : 5001 in 1030.058201 s
# Total files completed : 5101 in 1067.074369 s
# Total files completed : 5201 in 1090.743311 s
# Total files completed : 5301 in 1117.644611 s
# Total files completed : 5401 in 1143.377613 s
# Total files completed : 5501 in 1164.376935 s
# Total files completed : 5601 in 1198.562379 s
# Total files completed : 5701 in 1223.148764 s
# Total files completed : 5801 in 1246.790853 s
# Total files completed : 5901 in 1278.789823 s
# Total files completed : 6001 in 1303.694572 s
# Total files completed : 6101 in 1335.640359 s
# Total files completed : 6201 in 1360.992741 s
# Total files completed : 6301 in 1393.762096 s
# Total files completed : 6401 in 1429.973771 s
# Total files completed : 6501 in 1455.569575 s
# Total files completed : 6601 in 1484.857525 s
# Total files completed : 6701 in 1510.128761 s
# Total files completed : 6801 in 1539.076968 s
# Total files completed : 6901 in 1569.315152 s
# Total files completed : 7001 in 1600.549459 s
# Total files completed : 7101 in 1626.541778 s
# Total files completed : 7201 in 1655.65715 s
# Total files completed : 7301 in 1685.381749 s
# Total files completed : 7401 in 1712.03654 s
# Total files completed : 7501 in 1742.044448 s
# Total files completed : 7601 in 1776.807933 s
# Total files completed : 7701 in 1802.17713 s
# Total files completed : 7801 in 1829.625383 s
# Total files completed : 7901 in 1856.620855 s
# Total files completed : 8001 in 1884.212389 s
# Total files completed : 8101 in 1911.48972 s
# Total files completed : 8201 in 1938.217085 s
# Total files completed : 8301 in 1963.311831 s
# Total files completed : 8401 in 1995.65163 s
# Total files completed : 8501 in 2026.860479 s
# Total files completed : 8601 in 2055.36383 s
# Total files completed : 8701 in 2094.111181 s
# Total files completed : 8801 in 2122.032823 s
# Total files completed : 8901 in 2152.662328 s
# Total files completed : 9001 in 3128.916927 s
# Total files completed : 9101 in 4115.267189 s
# Total files completed : 9201 in 4197.030992 s
# Total files completed : 9301 in 5202.159005 s
# Total files completed : 9401 in 6267.550847 s
# Total files completed : 9501 in 7300.843382 s
# Total files completed : 9601 in 8393.01523 s
# Total files completed : 9701 in 10358.821946 s
# Total files completed : 9801 in 11436.901048 s
# Total files completed : 9901 in 12467.395676 s
# Total files completed : 10001 in 14054.879482 s
# Total files completed : 10101 in 15064.786938 s
# Total files completed : 10201 in 16117.800674 s
# Total files completed : 10301 in 16765.276269 s
# Total files completed : 10401 in 17806.726894 s
# Total files completed : 10501 in 18836.178366 s
# Total files completed : 10601 in 20073.197004 s
#
# ====== Current Directory : rbi_notification_2023_1991 ======
# Total files completed : 1 in 0.023125 s
# Completed!

# %%
dir_data_path_current
# Out:
# '/Users/saloni/Desktop/rag-ui/data/notification_1991_2023/'
